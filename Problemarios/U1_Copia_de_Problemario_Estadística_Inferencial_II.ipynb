# %% [markdown]
# <a href="https://colab.research.google.com/github/marieee005/EstadisticaVerano2026/blob/main/ProblemarioU1/Copia_de_Problemario_Estad%C3%ADstica_Inferencial_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 1. Regresión lineal simple y correlación

# %% [markdown]
# ## Medidas de dispersión
# Suma de los cuadrados de las desviaciones de los valores de $X$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (X_i - \bar{X})^2 $$
# Suma de los productos de las desviaciones de los valores de $X$ y $Y$ con respecto a sus medias:
# $$S_{xy} = \sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})$$
# Suma de los cuadrados de las desviaciones de los valores de $Y$ con respecto a su media:
# $$ S_{yy} = \sum_{i=1}^{n} (Y_i - \bar{Y})^2 $$

# %% [markdown]
# ## Coeficiente de correlación y de determinación
# Coeficiente de correlación de Pearson:
# $$ r = \frac{S_{xy}}{\sqrt{S_{xx} \cdot S_{yy}}} $$
# Coeficiente de determinación:
# $$ r^2 $$

# %% [markdown]
# ## Recta de regresión ajustada
# La regresión lineal ajustada se representa mediante estadísticos:
# $$ \hat{Y} = b_0 + b_1 X $$
# donde $\hat{Y}$ representa el valor de $Y$ obtenido mediante la recta de regresión ajustada (no la verdadera $Y$). Los estadísticos $b_0$ y $b_1$ se calculan de la siguiente manera:
#
# $$b_1 = \frac{S_{xy}}{S_{xx}}$$
#
# $$ b_0 = \bar{Y} - b_1 \bar{X} $$

# %% [markdown]
# ## Cálculo de residuales
# Residuales:
# $$e_i = Y_i - \hat{Y}_i$$

# %% [markdown]
# ## Sumas de cuadrados SS (Sum of Squares)
# Suma de los Cuadrados de los Errores:
# $$ SSE = \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2 = \sum_{i=1}^n e_i^2$$
# Suma total de cuadrados:
# $$SST = \sum_{i=1}^{n} (Y_i - \bar{Y})^2$$
# Suma de cuadrados de regresión:
# $$SSR = \sum_{i=1}^{n} (\hat{Y_i} - \bar{Y})^2$$
# - SST: Mide la variabilidad total de los datos observados.
# - SSR: Mide la variabilidad de los datos que el modelo de regresión explica.
# - SSE: Mide la variabilidad no explicada por el modelo (es decir, los residuos).

# %% [markdown]
# ## Intervalo de confianza
# Estadístico de prueba _t_:
# $$t = \frac{b_1}{SE(b_1)}$$
# Error estándar de $b_1$:
# $$SE(b_1) = \frac{\sqrt{SSE / (n-2)}}   {\sqrt{S_{xx}} }$$
# o
# $$SE(b_1) = \frac{\sqrt{\sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2  / (n-2)}}   {\sqrt{S_{xx}} }$$
#
# Intervalo de confianza para $b_1$:
# $$b_1 - t_{\alpha/2} \cdot SE(b_1) \lt \beta_1 \lt b_1 + t_{\alpha/2} \cdot SE(b_1)$$
# donde $n$ representa la cantidad de pares de datos.

# %% [markdown]
# ## Comprobación de supuestos
# Comprobar suposiciones:
# - Test de shapiro a los residuales $e_i$: Para comprobar si la distribución es normal sobre la recta.
# - Grafico $X$ vs $Y$: Para observar si los datos soportan la suposición de linealidad.
# - Gráfico de residuales: Para observar si los datos soportan la suposición de linealidad, complementario al coeficiente de correlación
# - Test de Breusch-Pagan: Para detectar heteroscedasticidad en regresion lineal

# %% [markdown]
# Test de Shapiro:<br>
# `from scipy.stats import shapiro`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_sh = shapiro(data)`<br>
# - $H_0$: Los datos siguen una distribución normal
# - $H_1$: Los datos no siguen una distribución normal

# %% [markdown]
# Test de Breusch-Pagan:<br>
# `from statsmodels.stats.api import het_breuschpagan`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_bp, _, _ = het_breuschpagan(residuales, X)`
# - $H_0$: Hay homoscedasticidad
# - $H_1$: Hay heteroscedasticidad

# %% [markdown]
# ## ANOVA en regresión lineal
#
# | Fuente de variación | Suma de cuadrados (SS) | Grados de libertad (df) | Promedio de los cuadrados (MS) | Estadístico F |
# |---------------------|------------------------|--------------------------|--------------------------------|---------------|
# | Regresión  | $ SSR$ | $p$ | $MSR = \frac{SSR}{p}$ | $F = \frac{MSR}{MSE}$|
# | Error | $SSE$| $n - p - 1 $| $MSE = \frac{SSE}{n - p - 1} $|     |
# | Total | $SST $| $n - 1$|             |        |
#
# donde $p$ es el número de parámetros para la recta de regresión ajustada (en la regresión simple $p=1$). Las hipótesis son:
# $$H_0: \beta_1 = 0$$
# $$H_1: \beta_1 \ne 0 $$

# %% [markdown]
# ## Problemario de la Unidad 1

# %% [markdown]
# ### Problema 1
# Un profesor intenta mostrar a sus estudiantes la importancia de los exámenes cortos, aun cuando el 90% de la calificación final esté determinada por los exámenes parciales. Él cree que cuanto más altas sean las calificaciones de los exámenes cortos, más alta será la calificación final. Seleccionó una muestra aleatoria de 15 estudiantes de su clase con los siguientes datos:
#
# | Promedio de exámenes cortos | Promedio final |
# |--------------|--------------|
# | 59 | 64 |
# | 92 | 84 |
# | 72 | 77 |
# | 90 | 80 |
# | 95 | 77 |
# | 87 | 81 |
# | 89 | 80 |
# | 77 | 84 |
# | 76 | 80 |
# | 65 | 69 |
# | 97 | 83 |
# | 42 | 40 |
# | 94 | 78 |
# | 62 | 65 |
# | 91 | 90 |
#
#
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd

df = pd.DataFrame({
    "promedio_examenes_cortos": [59, 92, 72, 90, 95, 87, 89, 77, 76, 65, 97, 42, 94, 62, 91],
    "promedio_final": [64, 84, 77, 80, 77, 81, 80, 84, 80, 69, 83, 40, 78, 65, 90]
})

df
# Out:
#     promedio_examenes_cortos  promedio_final
# 0                         59              64
# 1                         92              84
# 2                         72              77
# 3                         90              80
# 4                         95              77
# 5                         87              81
# 6                         89              80
# 7                         77              84
# 8                         76              80
# 9                         65              69
# 10                        97              83
# 11                        42              40
# 12                        94              78
# 13                        62              65
# 14                        91              90

# %% [markdown]
# **1. Establesca una variable dependiente ($Y$) y una variable independiente ($X$).**

# %% [markdown]
# + $Y$: Es el promedio final, porque es la variable que se quiere explicar o predecir.
# + $X$: Es el promedio examenes cortos, porque es la variable que el profesor cree que puede influir en el resultado.
#
# Esta elección es coherente, ya que busca analizar si mejorar en examenes cortos mejora el promedio fianl.

# %%
Y = df['promedio_final']
X = df['promedio_examenes_cortos']

# %% [markdown]
# **2.   Realice un diagrama de dispersión para estos datos.**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Definimos las variables X e Y a partir del DataFrame df
X = df['promedio_examenes_cortos']
Y = df['promedio_final']

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='#27F5E0',     # color de los puntos
    edgecolor='#27CCF5',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Promedio de exámenes cortos', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Promedio final', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.show() # Añadir para mostrar el gráfico

# %% [markdown]
# El diagrama muestra una tendencia positiva. Cuando aumentan las calificaciones de los exámenes cortos, también tiende a aumentar el promedio final. Los puntos no forman una línea perfecta, pero sí siguen una dirección clara hacia arriba.

# %% [markdown]
# **3. ¿Los datos soportan la suposición de linealidad?**

# %% [markdown]
# Sí se cumple de manera razonable el supuesto de linealidad. La nube de puntos se aproxima a una línea ascendente.

# %% [markdown]
# **4. Calcule el coeficiente de correlación e interprete el resultado.**

# %%
from scipy.stats import pearsonr
import pandas as pd

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación:  0.8646
# valor_p:  0.0000

# %% [markdown]
# El coeficiente es $r=0.8646$, lo que indica una correlación positiva fuerte. Como el valor-p es $0.000032$, se rechaza $H_0$ y se acepta que sí existe una relación lineal significativa entre los exámenes cortos y el promedio final.

# %% [markdown]
# **5. Calcule el coeficiente de determinación e interprete el resultado.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant (X)
modelo = sm.OLS (Y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

# %%
# Coeficiente de determinación
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculada)

print(f"Coeficiente de determinación: {r2: 0.2%}")
# Out:
# Coeficiente de determinación:  74.75%

# %% [markdown]
# Con el coeficiente de determinación de:
# $r^2=0.7475$

# %% [markdown]
# El valor $$r^2=0.7475$$ indica que el modelo explica aproximadamente el **74.75%** de la variación del promedio final. Esto significa que los exámenes cortos sí ayudan bastante a explicar el promedio final, aunque todavía hay otros factores que influyen.

# %%
24.526822+0.643180*(59)
# Out:
# 62.474441999999996

# %%
# modelo.predict([1,X])

modelo.predict([1,59])
# Out:
# array([62.47443345])

# %% [markdown]
# **6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.**

# %%
modelo.params
# Out:
# const                       24.526822
# promedio_examenes_cortos     0.643180
# dtype: float64

# %% [markdown]
# La ecuación de la recta es: $$y=24.526822+0.643180x$$

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Definimos las variables X e Y a partir del DataFrame df
X = df['promedio_examenes_cortos']
Y = df['promedio_final']

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='#27F5E0',     # color de los puntos
    edgecolor='#27CCF5',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Promedio de exámenes cortos', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Promedio final', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.show() # Añadir para mostrar el gráfico

# %% [markdown]
# Esto significa que por cada punto adicional en el promedio de exámenes cortos, el promedio final esperado aumenta aproximadamente **0.64 puntos**.

# %% [markdown]
# **7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)**

# %%
modelo.conf_int(alpha=0.05)
# Out:
#                                  0          1
# const                     6.441997  42.611646
# promedio_examenes_cortos  0.419219   0.867141

# %% [markdown]
# El intervalo para la pendiente es $0.4192, 0.8671$. Como el intervalo no contiene al cero, la pendiente es significativa; por lo tanto, sí se acepta que $X$ tiene efecto sobre $Y$.

# %% [markdown]
# **8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?**

# %%
residuales = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Definimos las variables X e Y a partir del DataFrame df
X = df['promedio_examenes_cortos']
Y = df['promedio_final']

# Gráfico de dispersión
plt.scatter(
    X, residuales,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='#27F5E0',     # color de los puntos
    edgecolor='#27CCF5',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculada * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Promedio de exámenes cortos', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Residuales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.show() # Añadir para mostrar el gráfico

# %% [markdown]
# Para los supuestos:
# + **Linealidad:** Sí se cumple, porque los datos siguen una tendencia recta positiva.
# + **Normalidad:** Se acepta porque Shapiro tiene $p=o.9018$ mayor a 0.05
# + **Homoscedasticidad:** Se acepta porque Breusch-Pagan tiene $p=0.02289$
# + **Independencia:** Se asume porque son estudiantes diferentes,

# %% [markdown]
# **9. Realice la prueba de Shapiro para los residuales y comente el resultado.**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# test de Shapiro-Wilk
# H0: Hay normalidad
# H1: No hay normalidad

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.901827735700704

# %% [markdown]
#  La hipótesis nula dice que los residuales siguen una distribución normal. Como $p=0.9018>0.05$, no se rechaza $H_0$; por lo tanto, se acepta que los residuales se comportan de forma normal.

# %% [markdown]
# **10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.**

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.2289

# %% [markdown]
# La hipótesis nula dice que existe homoscedasticidad, es decir, varianza constante en los residuales. Como $p=0.2289>0.05$, no se rechaza $H_0$; por eso se acepta que no hay problema importante de heteroscedasticidad.

# %% [markdown]
# **12. Realice una tabla ANOVA e interprete el resultado.**

# %%
# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols(
    '''promedio_final ~ promedio_examenes_cortos''',
    data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                             df       sum_sq      mean_sq          F    PR(>F)
# promedio_examenes_cortos   1.0  1538.228959  1538.228959  38.492412  0.000032
# Residual                  13.0   519.504375    39.961875        NaN       NaN

# %% [markdown]
# ### Problema 2
# William Hawkins, vicepresidente de personal de la International Motors, trabaja en la relación entre el salario de un trabajador y el porcentaje de ausentismo. Hawkins dividió el intervalo de salarios de International en 12 grados o niveles (1 es el menor grado, 12 el más alto) y después muestreó aleatoriamente a un grupo de trabajadores. Determinó el grado de salario de cada trabajador y el número de días que ese empleado había faltado en los últimos 3 años.
#
# | Categoría de salario | 11 | 10 | 8  | 5  | 9  | 7  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 18 | 17 | 29 | 36 | 11 | 28 | 35 |
#
# | Categoría de salario | 11 | 8  | 7  | 2  | 9  | 8  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 14 | 20 | 32 | 39 | 16 | 31 | 40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd

df = pd.DataFrame({
    "salario": [11,10,8,5,9,7,3,11,8,7,2,9,8,3],
    "ausencias": [18,17,29,36,11,28,35,14,20,32,39,16,31,40]
})

df
# Out:
#     salario  ausencias
# 0        11         18
# 1        10         17
# 2         8         29
# 3         5         36
# 4         9         11
# 5         7         28
# 6         3         35
# 7        11         14
# 8         8         20
# 9         7         32
# 10        2         39
# 11        9         16
# 12        8         31
# 13        3         40

# %% [markdown]
# 1. **Establesca una variable dependiente ($Y$) y una variable independiente ($X$).**
# + $Y$: es el salario, porque es la variable que se desea explicar ya que busca analizar si faltar mas días se relaciona con un menor nivel salarial.
# + $X$: son las ausencias,porque puede influir en la categoría de salario.

# %%
Y = df['salario']
X = df['ausencias']

# %% [markdown]
# 2. **Realice un diagrama de dispersión para estos datos.**

# %%
import matplotlib.pyplot as plt

# Definimos las variables X e Y a partir del DataFrame df
Y = df['salario']
X = df['ausencias']

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='#D327F5',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'ausencias', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'salario', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.show() # Added to display the plot

# %% [markdown]
# El diagrama muestra una tendencia descendente. Esto significa que, en general los trabajadores con más ausencias tienden a tener una categoría salarial más baja.

# %% [markdown]
# 3. **¿Los datos soportan la suposición de linealidad?**
#
# Sí, porque existe una tendencia, pero en sentido negativo, los puntos se acomodan alrededor de una línea descendente, por lo que la regresión lineal simpre es adecuada para este problema.

# %% [markdown]
# 4. **Calcule el coeficiente de correlación e interprete el resultado.**
#
# El coeficiente de correlación es $r=-0.8801$, este valor indica que este valor indica que la correlación es fuerte, dado que está muy cerca de **1**. Además, el que sea negativa, implica que aumentar las ausencias ($X$), disminuye el salario ($Y$).

# %%
from scipy.stats import pearsonr
import pandas as pd

df = pd.DataFrame({
    "salario": [11,10,8,5,9,7,3,11,8,7,2,9,8,3],
    "ausencias": [18,17,29,36,11,28,35,14,20,32,39,16,31,40]
})

X = df['ausencias']
Y = df['salario']

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación: -0.8801
# valor_p:  0.0000

# %% [markdown]
# 5. **Calcule el coeficiente de determinación e interprete el resultado.**
#
# El coeficiente de determinación es $r^2=0.7746$ indica que con las ausencias se esta justificando en un **77.46%** la varibilidad en los salarios. Por lo que el modelo puede tener una buena capacidad de predicción.

# %%
import statsmodels.api as sm
x_constante = sm.add_constant (X)
modelo = sm.OLS (Y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

# %%
# Coeficiente de determinación
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculada)
print(f"Coeficiente de determinación: {r2: 0.2%}")
# Out:
# Coeficiente de determinación:  77.46%

# %% [markdown]
# 6. **Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.**

# %%
modelo.params
# Out:
# const        14.058843
# ausencias    -0.261814
# dtype: float64

# %% [markdown]
# La ecuación de la recta es:
#
# $$
# \hat{y}=14.058843-0.261814x
# $$

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Definimos las variables X e Y a partir del DataFrame df
X = df['ausencias']
Y = df['salario']

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='#D327F5',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Ausencias', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Categoría de salario', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend(
    loc='best',
    fontsize=10
)

# %% [markdown]
# La pendiente negativa significa que por cadad ausencia adicional, la categoría salarial esperada disminuye aproximadamente 0.26 niveles.

# %% [markdown]
# 7. **Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)**
#
#
# La recta tiene la forma $$y=b_0+b_1x$$

# %% [markdown]
# El verdadero $b_0$ está entre $11.597445$ y $16.530241$ con una confianza de salario del 95%. esto indica que una persona sin ausencias ($x=0$) tiene una categoría de salario ($y$) que está entre estos dos valores.
#
# El verdadero calor de $b_1$ está entre $-0.350638$ y $-0.172989$ con un 95% de confianza. Dado que dentro de este intervalo no está el valor de cero, entoces la relación es significativa. también indica que por cada falta se peirde entre 0.172989 y o.350638 en la categoría de salario.

# %%
modelo.conf_int(alpha=0.05)
# Out:
#                    0          1
# const      11.587445  16.530241
# ausencias  -0.350638  -0.172989

# %% [markdown]
# 8. **Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?**

# %%
residuales = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, residuales,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='#D327F5',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculada * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Ausencias', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Residuales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend(
    fontsize=10,
    loc='best'
)

# %% [markdown]
# Para los supuestos:
# + **Linealidad**: Parece que sí cumple, porque los residuales no muestran una curva clara.
# + **Normalidad:** Sí cumple con la normalidad, porque Shapiro tiene $p=0.4173$.
# + **Homoscedasticidad:** Sí cumple con la homocedasticidad, porque Breusch-Pagan tiene $p=0.8955$
# + **Independencia:** Sí cumple la independecia, porque son trabajadores diferentes.

# %% [markdown]
# 9. **Realice la prueba de Shapiro para los residuales y comente el resultado.**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# test de Shapiro-Wilk
# H0: Hay normalidad
# H1: No hay normalidad

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.4172971767713699

# %% [markdown]
# La hipotesís nula indica que los residuales son normales como $p=0.4172 > 0.05$, no se rechaza $H_0$, por lo tanto, se acepta que los residuales tienen un comportamiento aproximadamente normal.

# %% [markdown]
# 10. **Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.**

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.8955

# %% [markdown]
# La hipótesis nula indica que hay homoscedasticidad. como $p=0.8955>0.05$, no se rechaza $H_0$, por eso se acepta que la varianza de los residuales es constante y no hay evidencia de heteroscedasticidad.

# %% [markdown]
# 11. **Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.**

# %% [markdown]
# Sí el modelo cumple con todos los supuestos, es confianble para interpolación.

# %%
# mínimo ausencias: 11
# máximo ausencias: 40

# interpolar valores de x entre 11 y 40

# interpolar 1
y_25 = modelo.predict([1,25])
y_32 = modelo.predict([1,32])

print(f"Para x = 25, y = {y_25[0]: 0.4f}")
print(f"Para x = 32, y = {y_32[0]: 0.4f}")
# Out:
# Para x = 25, y =  7.5135
# Para x = 32, y =  5.6808

# %%
df["salario_predicho"] = y_calculada
df
# Out:
#     salario  ausencias  salario_predicho
# 0        11         18          9.346197
# 1        10         17          9.608011
# 2         8         29          6.466247
# 3         5         36          4.633551
# 4         9         11         11.178893
# 5         7         28          6.728060
# 6         3         35          4.895365
# 7        11         14         10.393452
# 8         8         20          8.822570
# 9         7         32          5.680806
# 10        2         39          3.848110
# 11        9         16          9.869824
# 12        8         31          5.942619
# 13        3         40          3.586296

# %% [markdown]
# La extrapolación siempre debe hacerse con cuidado, aunque cumpla con todos los supuestos.

# %%
# mínimo ausencias: 11
# máximo ausencias: 40

# extrapolar, valores de x entre 11 y 40

y_10 = modelo.predict([1,10])

print(f"Para x = 10, y = {y_10[0]: 0.4f}")
# Out:
# Para x = 10, y =  11.4407

# %% [markdown]
# Con 10 ausencias se espera que el empleado tena una categoría de salario de 11. Este valor se obtuvo por medio de extrapolación, por lo que se toma con reservas.

# %% [markdown]
# 12. **Realice una tabla ANOVA e interprete el resultado.**

# %%
# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols('''salario ~ ausencias''', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#              df     sum_sq    mean_sq          F    PR(>F)
# ausencias   1.0  87.034348  87.034348  41.243954  0.000033
# Residual   12.0  25.322795   2.110233        NaN       NaN

# %% [markdown]
# Sí hay correlación porque el valor-p de $0.000033$ es menor a un nivel de significancia $\alpha=0.05$.
#
# en los residuales del anova se puede ver (investigar)

# %% [markdown]
# ### Problema 3
# A menudo, quienes hacen la contabilidad de costos estiman los gastos generales con base en el nivel de producción. En Standard Knitting Co. han reunido información acerca de los gastos generales y las unidades producidas en diferentes plantas.
#
# | Gastos generales | 191 | 170 | 272 | 155 | 280 | 173 | 234 | 116 | 153 | 178 |
# |------------------|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|
# | Unidades        |  40 |  42 |  53 |  35 |  56 |  39 |  48 |  30 |  37 |  40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd

df = pd.DataFrame({
    "Gastos Generales": [191,170,272,155,280,173,234,116,153,178],
    "Unidades": [40,42,53,35,56,39,48,30,37,40]
})
df.rename(columns={'Gastos Generales': 'Gastos_Generales'}, inplace=True)
df
# Out:
#    Gastos_Generales  Unidades
# 0               191        40
# 1               170        42
# 2               272        53
# 3               155        35
# 4               280        56
# 5               173        39
# 6               234        48
# 7               116        30
# 8               153        37
# 9               178        40

# %%
Y = df['Gastos_Generales']
X = df['Unidades']

# %% [markdown]
# 1. **Establesca una variable dependiente ($Y$) y una variable independiente ($X$).**
#
# + $Y$: Es Gastos Generales porque los gastos dependen del nivel de producción.
# + $X$: Es Unidades porque representa el nivel de producción que puede provocar cambios en los costos.

# %% [markdown]
# 2. **Realice un diagrama de dispersión para estos datos.**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='green',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Unidades', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Gastos Generales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# El diagrama muestra una tendencia positiva muy clara. A medida que aumentan las unidades producidas, también aumentan los gastos generales.

# %% [markdown]
# 3. **¿Los datos soportan la suposición de linealidad?**

# %% [markdown]
# Sí se cumple el supuesto de linealidad. Los puntos están muy cerca de una línea simple se ajusta bien a estos datos.

# %% [markdown]
# 4. **Calcule el coeficiente de correlación e interprete el resultado.**

# %%
from scipy.stats import pearsonr
import pandas as pd

df = pd.DataFrame({
    "Gastos Generales": [191,170,272,155,280,173,234,116,153,178],
    "Unidades": [40,42,53,35,56,39,48,30,37,40]
})

X = df['Unidades']
Y = df['Gastos Generales']

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación:  0.9835
# valor_p:  0.0000

# %% [markdown]
# El coeficiente es $r=0.9835$, lo cual indica una correlación porsitiva muy fuerte y relación emtre producción y gastos.

# %% [markdown]
# 5. **Calcule el coeficiente de determinación e interprete el resultado.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant (X)
modelo = sm.OLS (Y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

# %%
# Coeficiente de determinación
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculada)

print(f"Coeficiente de determinación: {r2: 0.2%}")
# Out:
# Coeficiente de determinación:  96.73%

# %% [markdown]
# Con coeficiente de determinación de: $$r^2=0.9673$$
#
# indica que las unidades producidas explican aproximadamente el $r^2=0.9673$ o el *96.73%* de la variación en los gastos generales. Esto significa que el modelo explica casi toda la variabilidad.

# %% [markdown]
# 6. **Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.**

# %%
modelo.params
# Out:
# const      -80.442857
# Unidades     6.491497
# dtype: float64

# %% [markdown]
# La ecuación de la recta es:
# $$y=-80.442857+6.491497$$

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='green',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Unidades', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Gastos Generales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend(
    loc='best',
    fontsize=10
)

# %% [markdown]
# La pendiente indica que por cada unidad adicional producida los gastos generales aumentan aproximadamente 6.49 unidades.

# %% [markdown]
# 7. **Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)**

# %%
modelo.conf_int(alpha=0.05)
# Out:
#                    0          1
# const    -121.986373 -38.899341
# Unidades    5.518450   7.464543

# %% [markdown]
# El intervalo para la pendiente es de $5.518450,7.464543$, como no incluye cero, la pendiente es significativa por lo tanto, sí se acepta que las unidades producidas explican los gastos generales.

# %% [markdown]
# 8. **Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?**

# %%
residuales = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, residuales,      # <--------------------------------------------------------
    marker="o",       # forma: googlear "matplotlib.markers"
    color='green',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculada * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Unidades', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Residuales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend(
    fontsize=10,
    loc='best'
)

# %% [markdown]
# Para los supuestos:
#
# + **Linealidad:** Sí se cumple de forma razonable, porque los residuales no muestran una curva marcada.
# + **Normalidad:** Sí se acepta, porque Shapiro tiene valor-p de 0.2205 > 0.05, no se rechaza la normalidad
# + **Homoscedasticidad:** Sí se acepta, porque Breusch-Pagan tiene valor-p 0.9858>0.05, la varianza de los residuales parece constante.
# + **Independencia:** Se asume, porque los datos provienen de plantas diferentes.

# %% [markdown]
# 9. **Realice la prueba de Shapiro para los residuales y comente el resultado.**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, Shapiro-Wilk es el más confiable
# n >= 30, Histograma o Q-Q plot

# test de Shapiro-Wilk
1
# H0: Hay normalidad    0.4172971767713699
0.05
# H1: No hay normalidad
0

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.22045077017698533

# %% [markdown]
# 10. **Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.**

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.9858

# %% [markdown]
# La hipótesis nula dice que existe homoscedasticidad. Como $p=0.9858$. No se rechaza $H_0$, entoces se acepta que la varianza de los residuales es constante.

# %% [markdown]
# 11. **Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.**

# %%
# mínimo unidades: 30
# máximo unidades: 56

# interpolar, valores de x entre 30 y 56

# interpolar
y_33 = modelo.predict([1, 33])
y_41 = modelo.predict([1, 41])

print(f"Para x = 33, y =  {y_33[0]: 0.4f}")
print(f"Para x = 41, y =  {y_41[0]: 0.4f}")
# Out:
# Para x = 33, y =   133.7765
# Para x = 41, y =   185.7085

# %%
y_calculada = modelo.predict(x_constante)
df["Gastos_predicho"] = y_calculada.round()
df
# Out:
#    Gastos Generales  Unidades  Gastos_predicho
# 0               191        40            179.0
# 1               170        42            192.0
# 2               272        53            264.0
# 3               155        35            147.0
# 4               280        56            283.0
# 5               173        39            173.0
# 6               234        48            231.0
# 7               116        30            114.0
# 8               153        37            160.0
# 9               178        40            179.0

# %%
# mínimo unidades: 30
# máximo unidades: 56

# Extrapolar, valores de x que no estén entre 30 y 56

y_25 = modelo.predict([[1, 25]])

print(f"Para x = 25, y =  {y_25[0]: 0.4f}")
# Out:
# Para x = 25, y =   81.8446

# %% [markdown]
# 12. **Realice una tabla ANOVA e interprete el resultado.**

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
import pandas as pd

# Re-initialize df with data for Problema 3
df = pd.DataFrame({
    "Gastos Generales": [191,170,272,155,280,173,234,116,153,178],
    "Unidades": [40,42,53,35,56,39,48,30,37,40]
})
df.rename(columns={'Gastos Generales': 'Gastos_Generales'}, inplace=True)

# Y ~ X
modelo_lineal = ols('Gastos_Generales ~ Unidades', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#            df        sum_sq       mean_sq           F        PR(>F)
# Unidades  1.0  24778.042517  24778.042517  236.669535  3.167080e-07
# Residual  8.0    837.557483    104.694685         NaN           NaN

# %% [markdown]
# El resultado muestra que el valor F es de $236.67$ y el $valor-p= 3.167080e-07$. Dado que el valor-p es significativamente menor que un nivel de significancia de 0.05, rechazamos la hipótesis nula y concluimos que las *Unidades* tienen un efecto lineal estadísticamente significativo sobre los *Gastos Generales*.

# %% [markdown]
# ### Problema 4
# Las ventas de línea blanca varían según el estado del mercado de casas nuevas: cuando las ventas de casas nuevas son buenas, también lo son las de lavaplatos, lavadoras de ropa, secadoras y refrigeradores.
# Una asociación de comercio compiló los siguientes datos históricos (en miles de unidades) de las ventas de línea blanca y la construcción de casas.
#
# | Construcción de casas (miles) | Ventas de línea blanca (miles) |
# |-------------------------------|--------------------------------|
# | 2.0                           | 5.0                            |
# | 2.5                           | 5.5                            |
# | 3.2                           | 6.0                            |
# | 3.6                           | 7.0                            |
# | 3.7                           | 7.2                            |
# | 4.0                           | 7.7                            |
# | 4.2                           | 8.4                            |
# | 4.6                           | 9.0                            |
# | 4.8                           | 9.7                            |
# | 5.0                           | 10.0                           |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd

df = pd.DataFrame({
    "Construccion de casas": [2.0, 2.5, 3.2, 3.6, 3.7, 4.0, 4.2, 4.6, 4.8, 5.0],
    "Ventas de linea blanca": [5.0, 5.5, 6.0, 7.0, 7.2, 7.7, 8.4, 9.0, 9.7, 10.0]
})
df
# Out:
#    Construccion de casas  Ventas de linea blanca
# 0                    2.0                     5.0
# 1                    2.5                     5.5
# 2                    3.2                     6.0
# 3                    3.6                     7.0
# 4                    3.7                     7.2
# 5                    4.0                     7.7
# 6                    4.2                     8.4
# 7                    4.6                     9.0
# 8                    4.8                     9.7
# 9                    5.0                    10.0

# %% [markdown]
# 1. **Establesca una variable dependiente ($Y$) y una variable independiente ($X$).**
#
# + $Y$: Ventas de línea blanca, ya que las ventas dependen de la construcción de casas.
# + $X$: Construcción de casas, ya que la construcción de casas es la variable que influye en las ventas.

# %%
X = df['Construccion de casas']
Y = df['Ventas de linea blanca']

# %% [markdown]
# 2. **Realice un diagrama de dispersión para estos datos.**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Construcción', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Ventas', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# El diagrama muestra una tendencia positiva muy marcada. Cuando aumenta la construcción de casas, tambien aumentan las ventas de línea blanca.

# %% [markdown]
# 3. **¿Los datos soportan la suposición de linealidad?**
#
# Sí, los datos en el diagrama de dispersión muestran una clara tendencia lineal, lo que sugiere que la suposición de linealidad se cumple.

# %% [markdown]
# 4. **Calcule el coeficiente de correlación e interprete el resultado.**

# %%
# Importar la función pearsonr desde scipy.stats
from scipy.stats import pearsonr

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlaciòn: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlaciòn:  0.9808
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de correlación para el Problema 4 es  0.9808 , lo que indica una relación lineal positiva muy fuerte entre la 'Construcción de casas' y las 'Ventas de línea blanca'. El valor-p de  0.0000  es significativamente menor que  0.05 , lo que confirma que esta correlación es estadísticamente significativa.

# %% [markdown]
# 5. **Calcule el coeficiente de determinación e interprete el resultado.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

# %%
# Coeficiente de determinación
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculada)

print(f"Coeficiente de determinación: {r2: 0.2%}")
# Out:
# Coeficiente de determinación:  96.19%

# %% [markdown]
# Con el coeficiente de determinación: $$r^2=0.9619$$ Esto significa que el $96.19\%$ de la variabilidad en las 'Ventas de línea blanca' se puede explicar por la 'Construcción de casas'. Este valor tan alto indica que el modelo de regresión lineal ajustado explica casi toda la variación en las ventas, lo que sugiere una relación lineal muy fuerte entre ambas variables.

# %% [markdown]
# 6. **Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.**

# %%
modelo.params
# Out:
# const                    1.016760
# Construccion de casas    1.737564
# dtype: float64

# %% [markdown]
# La ecuación de la recta de regresión ajustada es:
# $$\hat{y} = 1.016760 + 1.737564 x$$

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='-',        # estilo de línea
    label='Recta de Regresión Ajustada'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Construcción', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Ventas', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend(
    loc='best',
    fontsize=10
)

plt.show()

# %% [markdown]
# Esto significa que por cada unidad adicional en construcción de casa, las ventas esperadas de línea blanca aumentan aproximadamente 1.73 unidades.

# %% [markdown]
# 7. **Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)**

# %%
modelo.conf_int(alpha=0.05)
# Out:
#                               0         1
# const                 -0.074848  2.108368
# Construccion de casas  1.455693  2.019435

# %% [markdown]
# El intervalo para la pendiente es de 1.455693,2.019435. Como el intervalo no incluye cero, la pendiente es significativa, por eso se acepta que la construcción de casa sí influye en las ventas.

# %% [markdown]
# 8. **Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?**

# %%
residuales = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, residuales,      # <--------------------------------------------------------
    marker="o",       # forma: googlear "matplotlib.markers"
    color='yellow',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculada * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Construcción', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Ventas', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend(
    fontsize=10,
    loc='best'
)

# %% [markdown]
# Para los supuestos:
#
# + **Linealidad:** Sí se cumple, porque los residuales no muestran una curva clara y el patrón general es estable.
# + **Normalidad:** Sí se acepta, porque Shapiro tiene valor-p = 0.8463, no se rechaza la normalidad.
# + **Homoscedasticidad:** Sí se acepta, porque Breusch-Pagan tiene valor-p = 0.1581, no hay evidencia fuerte de heteroscedasticidad.
# + **Independencia:** Se asume, porque los datos históricos son observaciones diferentes.

# %% [markdown]
# 9. **Realice la prueba de Shapiro para los residuales y comente el resultado.**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, Shapiro-Wilk es el más confiable
# n >= 30, Histograma o Q-Q plot

# test de Shapiro-Wilk
1
# H0: Hay normalidad    0.4172971767713699
0.05
# H1: No hay normalidad
0

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.8463507249054649

# %% [markdown]
# La hipótesis nula indica que los residuales siguen una distribución normal. Como $p=0.8464$, no se rechaza $H_0$, por lo tanto, se acepta normalidad en los residuales.

# %% [markdown]
# 10. **Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.**

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.1581

# %% [markdown]
# La hipótesis nula establece que hay homoscedasticidad. Como $p=0.1581$, no se rechaza $H_0$, por eso se acepta que la varianza de los residuales es aproximadamente constante.

# %% [markdown]
# 11. **Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.**

# %%
# mínimo construcción: 2.0
# máximo construcción: 5.0

# interpolar, valores de x entre 2.0 y 5.0

# interpolar
y_2_5 = modelo.predict([1, 2.5])
y_3_2 = modelo.predict([1, 3.2])

print(f"Para x = 2.5, y =  {y_2_5[0]: 0.4f}")
print(f"Para x = 3.2, y =  {y_3_2[0]: 0.4f}")
# Out:
# Para x = 2.5, y =   5.3607
# Para x = 3.2, y =   6.5770

# %%
df["Ventas_predicho"] = y_calculada.round()
df
# Out:
#    Construccion de casas  Ventas de linea blanca  Ventas_predicho
# 0                    2.0                     5.0              4.0
# 1                    2.5                     5.5              5.0
# 2                    3.2                     6.0              7.0
# 3                    3.6                     7.0              7.0
# 4                    3.7                     7.2              7.0
# 5                    4.0                     7.7              8.0
# 6                    4.2                     8.4              8.0
# 7                    4.6                     9.0              9.0
# 8                    4.8                     9.7              9.0
# 9                    5.0                    10.0             10.0

# %%
# mínimo construcción: 2.0
# máximo construcción: 5.0

# Extrapolar, valores de x que no estén entre 11 y 40

y_1_5= modelo.predict([[1, 1.5]])

print(f"Para x = 1.5, y =  {y_1_5[0]: 0.4f}")
# Out:
# Para x = 1.5, y =   3.6231

# %% [markdown]
# 12. **Realice una tabla ANOVA e interprete el resultado.**

# %%
# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
import pandas as pd

# Re-initialize df with data for Problema 4 and rename columns for ols compatibility
df = pd.DataFrame({
    "Construccion de casas": [2.0, 2.5, 3.2, 3.6, 3.7, 4.0, 4.2, 4.6, 4.8, 5.0],
    "Ventas de linea blanca": [5.0, 5.5, 6.0, 7.0, 7.2, 7.7, 8.4, 9.0, 9.7, 10.0]
})
df.rename(columns={'Construccion de casas': 'Construccion_de_casas', 'Ventas de linea blanca': 'Ventas_de_linea_blanca'}, inplace=True)

# Y ~ X
modelo_lineal = ols('Ventas_de_linea_blanca ~ Construccion_de_casas', data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                         df     sum_sq    mean_sq           F        PR(>F)
# Construccion_de_casas  1.0  25.976581  25.976581  202.069951  5.841003e-07
# Residual               8.0   1.028419   0.128552         NaN           NaN

# %% [markdown]
# En ANOVA, $H_0$ dice que la pendiente es cero, es decir, que la construcción no explica las ventas. Como el $Valor-p=5.84100e-07$, se rechaza $H_0$, por lo tanto el modelo sí es significativo.

# %% [markdown]
# ### Problema 5
# William C. Andrews, consultor de comportamiento organizacional de Victory Motorcycles, ha diseñado una prueba para mostrar a los supervisores de la compañía los peligros de sobrevigilar a sus trabajadores.
# Un trabajador de la línea de ensamble tiene a su cargo una serie de tareas complicadas. Durante el desempeño del trabajador, un inspector lo interrumpe constantemente para ayudarlo a terminar las tareas.
# El trabajador, después de terminar su trabajo, recibe una prueba psicológica diseñada para medir la hostilidad del trabajador hacia la autoridad
# (una alta puntuación implica una hostilidad baja). A ocho distintos trabajadores se les asignaron las tareas y luego se les interrumpió para darles instrucciones útiles un número variable de veces (línea X).
# Sus calificaciones en la prueba de hostilidad se dan en el renglón Y.
#
# | número interrupciones al trabajador |  5  | 10  | 10  | 15  | 15  | 20  | 20  | 25  |
# |-----------------------------------------|----|----|----|----|----|----|----|----|
# | calificación del trabajador en la prueba de hostilidad | 58  | 41  | 45  | 27  | 26  | 12  | 16  |  3  |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd

df = pd.DataFrame ({
    "numero_interrupciones_al_trabajador": [5, 10, 10, 15, 15, 20, 20, 25],
    "calificacion_del_trabajador_en_la_prueba_de_hostilidad": [58, 41, 45, 27, 26, 12, 16, 3]
})
df
# Out:
#    numero_interrupciones_al_trabajador  \
# 0                                    5
# 1                                   10
# 2                                   10
# 3                                   15
# 4                                   15
# 5                                   20
# 6                                   20
# 7                                   25
#
#    calificacion_del_trabajador_en_la_prueba_de_hostilidad
# 0                                                 58
# 1                                                 41
# 2                                                 45
# 3                                                 27
# 4                                                 26
# 5                                                 12
# 6                                                 16
# 7                                                  3

# %% [markdown]
# 1. **Establesca una variable dependiente ($Y$) y una variable independiente ($X$).**
#
# + $Y$: Calificación del trabajador en la prueba de hostilidad, ya que es la variable que se ve afectada por el número de interrupciones.
# + $X$: Número de interrupciones al trabajador, ya que es la variable que se manipula o influye.

# %%
Y = df['calificacion_del_trabajador_en_la_prueba_de_hostilidad']
X = df['numero_interrupciones_al_trabajador']

# %% [markdown]
# 2. **Realice un diagrama de dispersión para estos datos.**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='red',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Numero de interrupciones al trabajador', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Calificación del trabajador en prueba de hostilidad', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# El diagrama muestra una tendencia negativa muy clara. Cuando aumentan las interrupciones, la calificación en la prueba disminuye.

# %% [markdown]
# 3. **¿Los datos soportan la suposición de linealidad?**
#
# Sí, los datos en el diagrama de dispersión muestran una clara tendencia lineal negativa, lo que sugiere que la suposición de linealidad se cumple. A medida que el número de interrupciones aumenta, la calificación de hostilidad tiende a disminuir.

# %% [markdown]
# 4. **Calcule el coeficiente de correlación e interprete el resultado.**

# %%
# Importar la función pearsonr desde scipy.stats
from scipy.stats import pearsonr

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlaciòn: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlaciòn: -0.9928
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de correlación $$r=-0.9928$$ indica una relación lineal negativa extremadamente fuerte entre el número de interrupciones al trabajador y su calificación en la prueba de hostilidad. El $valor-p=0.0000$ es muy pequeño, confirmando que esta correlación es estadísticamente significativa.

# %% [markdown]
# 5. **Calcule el coeficiente de determinación e interprete el resultado.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

# %%
# Coeficiente de determinación
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculada)

print(f"Coeficiente de determinación: {r2: 0.2%}")
# Out:
# Coeficiente de determinación:  98.58%

# %% [markdown]
# El coeficiente de determinación: $$r^2 = 0.9858$$ significa que el 98.58% de la variabilidad en la ***calificación del trabajador en la prueba de hostilidad*** puede ser explicada por el ***número de interrupciones al trabajador***. Esto sugiere un modelo de regresión lineal muy preciso y con un poder explicativo muy alto.

# %% [markdown]
# 6. **Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.**

# %%
modelo.params
# Out:
# const                                  70.5
# numero_interrupciones_al_trabajador    -2.8
# dtype: float64

# %% [markdown]
# La ecuación de la recta es:
#
# $$y=70.5-2.8x$$

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='red',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Número de interrupciones', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Calificación de prueba de hospitalidad', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

#Marielena Carvajal Becerra

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend(
    loc='best',
    fontsize=10
)

# %% [markdown]
# La pendiente negativa indica que por cada interrupción adicional, la calificación esperada baja aproximadamente 2.8 puntos. Como una calificación alta implica menor hostilidad, al bajar la calificación se interpreta que la hostilidad aumenta.

# %% [markdown]
# 7. **Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)**

# %%
modelo.conf_int(alpha=0.05)
# Out:
#                                              0          1
# const                                65.051384  75.948616
# numero_interrupciones_al_trabajador  -3.136296  -2.463704

# %% [markdown]
# El intervalo de confianza del 95% para la intercepción ($b_0$) es entre $65.051384$ y $75.948616$. Esto significa que si no hay interrupciones $X=0$, la calificación de hostilidad esperada está en este rango con un 95% de confianza.
#
# Para la pendiente ($b_1$), el intervalo de confianza del 95% es entre $-3.136296$ y $-2.463704$. Dado que este intervalo no incluye el cero, podemos concluir que existe una relación lineal significativa entre el número de interrupciones y la calificación de hostilidad. Por cada interrupción adicional, la calificación de hostilidad disminuye entre aproximadamente 2.46 y 3.13 puntos, con un 95% de confianza.

# %% [markdown]
# 8. **Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?**

# %%
residuales = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, residuales,      # <--------------------------------------------------------
    marker="o",       # forma: googlear "matplotlib.markers"
    color='red',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculada * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Número de interrupciones', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Calificación de la prueba de hospitalidad', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend(
    fontsize=10,
    loc='best'
)

# %% [markdown]
# Para los supuestos:
#
# + **Linealidad:** El gráfico de residuales no muestra un patrón claro o curvatura, lo que apoya la suposición de linealidad.
# + **Normalidad:** Sí se acepta, porque Shapiro tiene valor-p 0.0548, sin embargo, está cerca del límite, por lo que se debe interpretar con cuidado.
# + **Homoscedasticidad:** La dispersión de los residuales parece ser constante a lo largo de los valores de X, lo que apoya la suposición de homoscedasticidad (Sí se acepta).
# + **Independencia:** La independencia de los residuales se asume al ser datos de diferentes trabajadores y al no observarse patrones de autocorrelación en el gráfico.

# %% [markdown]
# 9. **Realice la prueba de Shapiro para los residuales y comente el resultado.**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, Shapiro-Wilk es el más confiable
# n >= 30, Histograma o Q-Q plot

# test de Shapiro-Wilk
1
# H0: Hay normalidad    0.4172971767713699
0.05
# H1: No hay normalidad
0

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.054816491127669634

# %% [markdown]
# Para la prueba de Shapiro-Wilk:
#
# + Hipótesis Nula ($H_0$): Los residuales siguen una distribución normal.
# + Hipótesis Alternativa ($H_1$): Los residuales no siguen una distribución normal.
#
# Dado que el valor-p (Shapiro) es *0.05481* (mayor que 0.05), no tenemos evidencia suficiente para rechazar la hipótesis nula. Por lo tanto, podemos asumir que los residuales siguen una distribución normal.

# %% [markdown]
# 10. **Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.**

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.2482

# %% [markdown]
# La hipótesis nula indica que hay homoscedasticidad. Como $p=0.2482$, no se rechaza $H_0$, entonces se acepta que no hay evidencia de heteroscedasticidad.

# %% [markdown]
# 11. **Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.**

# %%
# mínimo ausencias: 5
# máximo ausencias: 25

# Interpolación, valores de x entre 5 y 25

# Interpolar
y_12 = modelo.predict([1, 12])
y_18 = modelo.predict ([1, 18])

print(f"Para x = 12, y = {y_12[0]: 0.2f}")
print(f"Para x = 18, y = {y_18[0]: 0.2f}")
# Out:
# Para x = 12, y =  36.90
# Para x = 18, y =  20.10

# %%
df["numero_interrupciones_al_trabajador_predicho"] = y_calculada.round()
df
# Out:
#    numero_interrupciones_al_trabajador  \
# 0                                    5
# 1                                   10
# 2                                   10
# 3                                   15
# 4                                   15
# 5                                   20
# 6                                   20
# 7                                   25
#
#    calificacion_del_trabajador_en_la_prueba_de_hostilidad  \
# 0                                                 58
# 1                                                 41
# 2                                                 45
# 3                                                 27
# 4                                                 26
# 5                                                 12
# 6                                                 16
# 7                                                  3
#
#    numero_interrupciones_al_trabajador_predicho
# 0                                          56.0
# 1                                          42.0
# 2                                          42.0
# 3                                          28.0
# 4                                          28.0
# 5                                          15.0
# 6                                          15.0
# 7                                           1.0

# %% [markdown]
# **Interpolación:**
# + Para 12 interrupciones, la calificación de hostilidad esperada es $36.90$.
# + Para 18 interrupciones, la calificación de hostilidad esperada es $20.10$
#
# Estos valores son razonablemente confiables ya que se encuentran dentro del rango de datos observados (entre 5 y 25 interrupciones) y el modelo ha demostrado un buen ajuste.

# %%
# mínimo ausencias: 5
# máximo ausencias: 25

# Extrapolar, valores de x que no estén entre 5 y 25

y_30 = modelo.predict([[1, 30]])

print(f"Para x = 30, y =  {y_30[0]: 0.4f}")
# Out:
# Para x = 30, y =  -13.5000

# %% [markdown]
# **Extrapolación:**
# + Para 30 interrupciones, la calificación de hostilidad esperada es $-13.5000$.
#
# Este resultado, una calificación negativa, no tiene sentido en el contexto del problema, ya que la calificación de hostilidad no puede ser negativa. Esto resalta el peligro de la extrapolación: el modelo lineal puede no ser válido fuera del rango de datos observados. Aunque el modelo se ajusta bien a los datos dentro del rango, asumen que esta relación lineal continúa indefinidamente puede llevar a predicciones ilógicas.

# %% [markdown]
# 12. **Realice una tabla ANOVA e interprete el resultado.**

# %%
Y = df['calificacion_del_trabajador_en_la_prueba_de_hostilidad']
X = df['numero_interrupciones_al_trabajador']

# %%
# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols('''calificacion_del_trabajador_en_la_prueba_de_hostilidad ~ numero_interrupciones_al_trabajador''', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                                       df  sum_sq      mean_sq           F  \
# numero_interrupciones_al_trabajador  1.0  2352.0  2352.000000  415.058824
# Residual                             6.0    34.0     5.666667         NaN
#
#                                            PR(>F)
# numero_interrupciones_al_trabajador  9.090964e-07
# Residual                                      NaN

# %% [markdown]
# La hipótesis nula ($H_0$) establece que la pendiente de la regresión es igual a cero, lo que implica que no hay una relación lineal significativa entre el número de interrupciones y la calificación de hostilidad. La hipótesis alternativa ($H_1$) establece que la pendiente no es cero, indicando una relación lineal significativa.
#
# Dado que el valor-p $9.090964e-07$ es extremadamente pequeño (mucho menor que el nivel de significancia común de 0.05), rechazamos la hipótesis nula. Esto significa que existe una relación lineal estadísticamente significativa entre el número de interrupciones al trabajador y la calificación del trabajador en la prueba de hostilidad. En otras palabras, el número de interrupciones es un predictor significativo de la calificación de hostilidad.

# %%
# Marielena Carvajal Becerra
